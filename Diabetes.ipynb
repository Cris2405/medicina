# %% [markdown]
# <a href="https://colab.research.google.com/github/Cris2405/medicina/blob/main/Diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pandas as pd
import numpy as np
import datetime as dt
import missingno as msno 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go

url= "https://raw.githubusercontent.com/Cris2405/medicina/main/diabetes.csv"
df= pd.read_csv(url)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
print(df.isna().sum())
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df ['Glucose'] = df ['Glucose'].replace(0,np.nan)
df ['BloodPressure'] = df ['BloodPressure'].replace(0,np.nan)
df ['SkinThickness'] = df ['SkinThickness'].replace(0,np.nan)
df ['Insulin'] = df ['Insulin'].replace(0,np.nan)

# %%
print(df.isnull().sum())
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                           0
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
df.median()
# Out:
# Pregnancies                   3.0000
# Glucose                     117.0000
# BloodPressure                72.0000
# SkinThickness                29.0000
# Insulin                     125.0000
# BMI                          32.0000
# DiabetesPedigreeFunction      0.3725
# Age                          29.0000
# Outcome                       0.0000
# dtype: float64

# %%
df ['Glucose'] = df ['Glucose'].replace(np.nan,117)
df ['BloodPressure'] = df ['BloodPressure'].replace(np.nan,72)
df ['SkinThickness'] = df ['SkinThickness'].replace(np.nan,29)
df ['Insulin'] = df ['Insulin'].replace(np.nan,125)

# %%
#Diapositiva 26
print(df.isnull().sum())
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
print(df.groupby('Outcome').size())
# Out:
# Outcome
# 0    500
# 1    268
# dtype: int64

# %%
print(df.groupby('Age').size())
# Out:
# Age
# 21    63
# 22    72
# 23    38
# 24    46
# 25    48
# 26    33
# 27    32
# 28    35
# 29    29
# 30    21
# 31    24
# 32    16
# 33    17
# 34    14
# 35    10
# 36    16
# 37    19
# 38    16
# 39    12
# 40    13
# 41    22
# 42    18
# 43    13
# 44     8
# 45    15
# 46    13
# 47     6
# 48     5
# 49     5
# 50     8
# 51     8
# 52     8
# 53     5
# 54     6
# 55     4
# 56     3
# 57     5
# 58     7
# 59     3
# 60     5
# 61     2
# 62     4
# 63     4
# 64     1
# 65     3
# 66     4
# 67     3
# 68     1
# 69     2
# 70     1
# 72     1
# 81     1
# dtype: int64

# %%
#Pregnancies	Glucose	BloodPressure	SkinThickness	Insulin	BMI	DiabetesPedigreeFunction	Age
plt.figure(figsize=(15,20))
plt.subplot(4,4,1)
sns.boxplot(df['Pregnancies'])
plt.figure(figsize=(15,20))
plt.subplot(5,5,2)
sns.boxplot(df['Glucose'])
plt.figure(figsize=(15,20))
plt.subplot(6,6,3)
sns.boxplot(df['BloodPressure'])
plt.figure(figsize=(15,20))
plt.subplot(7,7,4)
sns.boxplot(df['SkinThickness'])
plt.figure(figsize=(15,20))
plt.subplot(4,4,5)
sns.boxplot(df['Insulin'])
plt.figure(figsize=(15,20))
plt.subplot(4,4,6)
sns.boxplot(df['BMI'])
plt.figure(figsize=(15,20))
plt.subplot(4,4,7)
sns.boxplot(df['DiabetesPedigreeFunction'])
plt.figure(figsize=(15,20))
plt.subplot(4,4,8)
sns.boxplot(df['Age'])
# Out:
# <Axes: >

# %%
df['Pregnancies']=df['Pregnancies'].clip(lower=df['Pregnancies'].quantile(0.5),upper=df['Pregnancies'].quantile(0.95))
df['BloodPressure']=df['BloodPressure'].clip(lower=df['BloodPressure'].quantile(0.5),upper=df['BloodPressure'].quantile(0.95))
df['SkinThickness']=df['SkinThickness'].clip(lower=df['SkinThickness'].quantile(0.10),upper=df['SkinThickness'].quantile(0.90))
df['Insulin']=df['Insulin'].clip(lower=df['Insulin'].quantile(0.25), upper=df['Insulin'].quantile(0.75))
df['BMI']=df['BMI'].clip(lower=df['BMI'].quantile(0.5), upper=df['BMI'].quantile(0.95))
df['DiabetesPedigreeFunction']=df['DiabetesPedigreeFunction'].clip(lower=df['DiabetesPedigreeFunction'].quantile(0.5),upper=df['DiabetesPedigreeFunction'].quantile(0.95))
df['Age']=df['Age'].clip(lower=df['Age'].quantile(0.5), upper=df['Age'].quantile(0.95))

# %%
plt.figure(figsize=(15,20))
plt.subplot(4,4,1)
sns.boxplot(df['Pregnancies'])
plt.figure(figsize=(15,20))
plt.subplot(5,5,2)
sns.boxplot(df['Glucose'])
plt.figure(figsize=(15,20))
plt.subplot(6,6,3)
sns.boxplot(df['BloodPressure'])
plt.figure(figsize=(15,20))
plt.subplot(7,7,4)
sns.boxplot(df['SkinThickness'])
plt.figure(figsize=(15,20))
plt.subplot(4,4,5)
sns.boxplot(df['Insulin'])
plt.figure(figsize=(15,20))
plt.subplot(4,4,6)
sns.boxplot(df['BMI'])
plt.figure(figsize=(15,20))
plt.subplot(4,4,7)
sns.boxplot(df['DiabetesPedigreeFunction'])
plt.figure(figsize=(15,20))
plt.subplot(4,4,8)
sns.boxplot(df['Age'])
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")
sns.countplot(x=df['Outcome'])
# Out:
# <Axes: xlabel='Outcome', ylabel='count'>

# %%
f, ax =plt.subplots(figsize=(20,10))
corr = df.corr("pearson")
dataplot = sns.heatmap(df.corr(), cmap="YlGnBu",annot=True)

# %%
import seaborn as sns

sns.set_theme()

g = sns.lmplot(data=df, x="Age", y="Glucose", hue="Outcome", height=5)
g.set_axis_labels("Insuline (mg/dl)","BloodPressure(mg/dl)")
